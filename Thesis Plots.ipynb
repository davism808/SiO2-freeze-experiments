# %%
import matplotlib.pyplot as plt
import pandas as pd

# Open and Read txtfile
file_path = r"C:\Users\dbail\Downloads\12 Week Data.txt"  
data = pd.read_csv(file_path, delimiter='\t')

# Assign columns to variables
depth = 'Depth'
Fridge_One_Week = 'A Fridge'
Fridge_Six_Weeks = 'B fridge'
Fridge_Twelve_Weeks = 'C fridge'
Freezer_One_Week = 'A -20'
Freezer_Six_Weeks = 'B -20'
Freezer_Twelve_Weeks = 'C -20'
Cryogenic_One_Week = 'A -80'
Cryogenic_Six_Weeks = 'B -80'
Cryogenic_Twelve_Weeks = 'C -80'

#Plotting 3 graphs in 1 row
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharex=True, sharey=True)

# Plot scatter plots
ax[0].scatter(data[Fridge_One_Week], data[depth], color='blue', label='Fridge One Week')
ax[0].scatter(data[Fridge_Six_Weeks], data[depth], color='green', label='Fridge Six Weeks')
ax[0].scatter(data[Fridge_Twelve_Weeks], data[depth], color='orange', label='Fridge Twelve Weeks')
ax[0].set_title('SiO2 Concentrations After Refrigeration')

ax[1].scatter(data[Freezer_One_Week], data[depth], color='blue', label='Freezer One Week')
ax[1].scatter(data[Freezer_Six_Weeks], data[depth], color='green', label='Freezer Six Weeks')
ax[1].scatter(data[Freezer_Twelve_Weeks], data[depth], color='orange', label='Freezer Twelve Weeks')
ax[1].set_title('SiO2 Concentrations After Freezing')

ax[2].scatter(data[Cryogenic_One_Week], data[depth], color='blue', label='Cryogenic One Week')
ax[2].scatter(data[Cryogenic_Six_Weeks], data[depth], color='green', label='Cryogenic Six Weeks')
ax[2].scatter(data[Cryogenic_Twelve_Weeks], data[depth], color='orange', label='Cryogenic Twelve Weeks')
ax[2].set_title('SiO2 Concentrations After Cryogenic Freezing')

# Reverse y-axis so depth is increasing
for axes in ax.flat:
    axes.invert_yaxis()

# Set labels and legends
for axes in ax.flat:
    axes.set_xlabel('Measured SiO2 Concentration')
    axes.set_ylabel('Depth')
    axes.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Open and Read txtfile
file_path = r"C:\Users\dbail\Downloads\12 Week Data.txt"  
data = pd.read_csv(file_path, delimiter='\t')

# Define the depths of interest
desired_depths = [5, 130, 269, 308, 402, 438, 473, 597, 715, 882, 1000]  # Replace with your desired depths

# Filter data based on desired depths
filtered_data = data[data['Depth'].isin(desired_depths)]

# Assign columns to variables
depth = 'Depth'
Fridge_One_Week = 'A Fridge'
Fridge_Six_Weeks = 'B fridge'
Fridge_Twelve_Weeks = 'C fridge'
Freezer_One_Week = 'A -20'
Freezer_Six_Weeks = 'B -20'
Freezer_Twelve_Weeks = 'C -20'
Cryogenic_One_Week = 'A -80'
Cryogenic_Six_Weeks = 'B -80'
Cryogenic_Twelve_Weeks = 'C -80'

# Plotting 3 graphs in 1 row
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharex=True, sharey=True)

# Plot scatter plots
ax[0].scatter(filtered_data[Fridge_One_Week], filtered_data[depth], color='blue', label='Fridge One Week')
ax[0].scatter(filtered_data[Fridge_Six_Weeks], filtered_data[depth], color='green', label='Fridge Six Weeks')
ax[0].scatter(filtered_data[Fridge_Twelve_Weeks], filtered_data[depth], color='orange', label='Fridge Twelve Weeks')
ax[0].set_title('SiO2 Concentrations After Refrigeration')

ax[1].scatter(filtered_data[Freezer_One_Week], filtered_data[depth], color='blue', label='Freezer One Week')
ax[1].scatter(filtered_data[Freezer_Six_Weeks], filtered_data[depth], color='green', label='Freezer Six Weeks')
ax[1].scatter(filtered_data[Freezer_Twelve_Weeks], filtered_data[depth], color='orange', label='Freezer Twelve Weeks')
ax[1].set_title('SiO2 Concentrations After Freezing')

ax[2].scatter(filtered_data[Cryogenic_One_Week], filtered_data[depth], color='blue', label='Cryogenic One Week')
ax[2].scatter(filtered_data[Cryogenic_Six_Weeks], filtered_data[depth], color='green', label='Cryogenic Six Weeks')
ax[2].scatter(filtered_data[Cryogenic_Twelve_Weeks], filtered_data[depth], color='orange', label='Cryogenic Twelve Weeks')
ax[2].set_title('SiO2 Concentrations After Cryogenic Freezing')

# Reverse y-axis so depth is increasing
for axes in ax.flat:
    axes.invert_yaxis()

# Set labels and legends
for axes in ax.flat:
    axes.set_xlabel('Measured SiO2 Concentration')
    axes.set_ylabel('Depth')
    axes.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Open and Read txtfile
file_path = r"C:\Users\dbail\Downloads\12 Week Data.txt"  
data = pd.read_csv(file_path, delimiter='\t')

# Assign columns to variables
depth = 'Depth'
Fridge_One_Week = 'A Fridge'
Fridge_Six_Weeks = 'B fridge'
Fridge_Twelve_Weeks = 'C fridge'
Freezer_One_Week = 'A -20'
Freezer_Six_Weeks = 'B -20'
Freezer_Twelve_Weeks = 'C -20'
Cryogenic_One_Week = 'A -80'
Cryogenic_Six_Weeks = 'B -80'
Cryogenic_Twelve_Weeks = 'C -80'

#Plotting 3 graphs in 1 row
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharex=True, sharey=True)

# Plot scatter plots
ax[0].scatter(data[Fridge_One_Week], data[depth], color='blue', label='Fridge One Week')
ax[0].scatter(data[Freezer_One_Week], data[depth], color='green', label='Freezer One Week')
ax[0].scatter(data[Cryogenic_One_Week], data[depth], color='orange', label='Cryogenic One Week')
ax[0].set_title('SiO2 Concentrations After One Week')

ax[1].scatter(data[Fridge_Six_Weeks], data[depth], color='blue', label='Fridge Six Weeks')
ax[1].scatter(data[Freezer_Six_Weeks], data[depth], color='green', label='Freezer Six Weeks')
ax[1].scatter(data[Cryogenic_Six_Weeks], data[depth], color='orange', label='Cryogenic Six Weeks')
ax[1].set_title('SiO2 Concentrations After 6 Weeks')

ax[2].scatter(data[Fridge_Twelve_Weeks], data[depth], color='blue', label='Fridge Twelve Weeks')
ax[2].scatter(data[Freezer_Twelve_Weeks], data[depth], color='green', label='Freezer Twelve Weeks')
ax[2].scatter(data[Cryogenic_Twelve_Weeks], data[depth], color='orange', label='Cryogenic Twelve Weeks')
ax[2].set_title('SiO2 Concentrations After 12 Weeks')

# Reverse y-axis so depth is increasing
for axes in ax.flat:
    axes.invert_yaxis()

# Set labels and legends
for axes in ax.flat:
    axes.set_xlabel('Measured SiO2 Concentration')
    axes.set_ylabel('Depth')
    axes.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Initialize figure and axes
fig, axs = plt.subplots(1, 1, figsize=(8, 6))  # Adjust rows and cols for more subplots if needed

# Scatter plot
axs.scatter(x=Fridge_One_Week, y=Freezer_One_Week, alpha=0.5, label='$R^{2}$ = '+str(round(np.corrcoef(Fridge_One_Week, Freezer_One_Week)[0, 1]**2, 4)))

# Optionally plot a trend line if needed
m, b = np.polyfit(Fridge_One_Week, Freezer_One_Week, 1)
axs.plot(Fridge_One_Week, m*Fridge_One_Week + b, color='gray')

# Set axes limits
axs.set_ylim(0, 170)
axs.set_xlim(0, 170)

# Set title and legend
axs.set_title('Nutrient Concentrations: Fridge vs. Freezer')
axs.legend()

# Add common x and y labels
fig.text(0.5, 0.04, 'Fridge One Week [UMOL/L]', ha='center', va='center', fontsize=12)
fig.text(0.04, 0.5, 'Freezer One Week [UMOL/L]', ha='center', va='center', rotation='vertical', fontsize=12)

# Adjust layout and save
plt.tight_layout()
plt.savefig('xyplots.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Initialize figure and axes
fig, axs = plt.subplots(1, 1, figsize=(8, 6))  # Adjust rows and cols for more subplots if needed

# Scatter plot with different colors for each set of dots
axs.scatter(x=Fridge_One_Week, y=Freezer_One_Week, alpha=0.5, label='Fridge vs Freezer', c='blue')
axs.scatter(x=Fridge_Six_Weeks, y=Freezer_Six_Weeks, alpha=0.5, label='Fridge vs Freezer (6 Weeks)', c='red')
axs.scatter(x=Fridge_Twelve_Weeks, y=Freezer_Twelve_Weeks, alpha=0.5, label='Fridge vs Freezer (12 Weeks)', c='green')

# Optionally plot trend lines for each set if needed
m1, b1 = np.polyfit(Fridge_One_Week, Freezer_One_Week, 1)
axs.plot(Fridge_One_Week, m1*Fridge_One_Week + b1, color='blue', linestyle='dashed')
m2, b2 = np.polyfit(Fridge_Six_Weeks, Freezer_Six_Weeks, 1)
axs.plot(Fridge_Six_Weeks, m2*Fridge_Six_Weeks + b2, color='red', linestyle='dashed')
m3, b3 = np.polyfit(Fridge_Twelve_Weeks, Freezer_Twelve_Weeks, 1)
axs.plot(Fridge_Twelve_Weeks, m3*Fridge_Twelve_Weeks + b3, color='green', linestyle='dashed')

# Set axes limits
axs.set_ylim(0, 160)
axs.set_xlim(0, 160)

# Set title and legend
axs.set_title('Nutrient Concentrations: Fridge vs. Freezer')
axs.legend()

# Add common x and y labels
fig.text(0.5, 0.04, 'Fridge [UMOL/L]', ha='center', va='center', fontsize=12)
fig.text(0.04, 0.5, 'Freezer [UMOL/L]', ha='center', va='center', rotation='vertical', fontsize=12)

# Adjust layout and save
plt.tight_layout()
plt.savefig('xyplots.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))  # 3 rows, 3 columns

# Titles for each subplot
titles = ['Fridge vs. Freezer (One Week)', 'Fridge vs. Cryogenic (One Week)',
          'Freezer vs. Cryogenic (One Week)', 'Fridge vs. Freezer (Six Weeks)',
          'Fridge vs. Cryogenic (Six Weeks)', 'Freezer vs. Cryogenic (Six Weeks)',
          'Fridge vs. Freezer (Twelve Weeks)', 'Fridge vs. Cryogenic (Twelve Weeks)',
          'Freezer vs. Cryogenic (Twelve Weeks)']

# Data for each subplot
data_sets = [(Fridge_One_Week, Freezer_One_Week), (Fridge_One_Week, Cryogenic_One_Week), (Freezer_One_Week, Cryogenic_One_Week),
             (Fridge_Six_Weeks, Freezer_Six_Weeks), (Fridge_Six_Weeks, Cryogenic_Six_Weeks), (Freezer_Six_Weeks, Cryogenic_Six_Weeks),
             (Fridge_Twelve_Weeks, Freezer_Twelve_Weeks), (Fridge_Twelve_Weeks, Cryogenic_Twelve_Weeks), (Freezer_Twelve_Weeks, Cryogenic_Twelve_Weeks)]

# Plotting each subplot
for i, (x_data, y_data) in enumerate(data_sets):
    row = i // 3
    col = i % 3
    axs[row, col].scatter(x=x_data, y=y_data, alpha=0.5)
    axs[row, col].set_title(titles[i])
    axs[row, col].set_xlabel('Fridge [UMOL/L]', fontsize=12)
    axs[row, col].set_ylabel('Freezer [UMOL/L]', fontsize=12)
    axs[row, col].set_xlim(0, 160)
    axs[row, col].set_ylim(0, 160)
    axs[row, col].plot(x_data, np.poly1d(np.polyfit(x_data, y_data, 1))(x_data), color='gray', linestyle='dashed')
    

# Adjust layout and save
plt.tight_layout()
plt.savefig('3x3_grid_plots_with_R2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 30
#      27     r_squared = np.corrcoef(x_data, y_data)[0, 1]**2
#      29     # Annotate R-squared value on plot
# ---> 30     axs[row, col].annotate('$R^{2}$ = {:.2f}'.format(r_squared), xy=(0.05, 0.85), xycoords='axes fraction', fontsize=12)
#      32 # Adjust layout and save
#      33 plt.tight_layout()
#
# IndexError: Replacement index 2 out of range for positional args tuple
